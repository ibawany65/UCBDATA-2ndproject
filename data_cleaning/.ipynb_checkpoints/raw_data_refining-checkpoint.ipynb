# %%
import pandas as pd

# %% [markdown]
# The raw data file "agg_region_datacenter_calc (rf_temp.agg_region_datacenter_calc) (rf_temp).csv" is too large to keep in the github repo, so it has been removed.

# %%
file = "agg_region_datacenter_calc (rf_temp.agg_region_datacenter_calc) (rf_temp).csv"
illinois_df = pd.read_csv(file,encoding="utf-16",sep='\t')
illinois_df.head()
# Out:
# /Users/dan/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Worksheet Filter  Measure Display  Number of Records  Avg Sale To List  \
# 0            Value              NaN                  1          0.825275
# 1            Value              NaN                  1          0.950521
# 2            Value              NaN                  1          0.967536
# 3            Value              NaN                  1          0.950804
# 4            Value              NaN                  1          0.938561
#
#   Avg Sale To List Mom Avg Sale To List Yoy City  Homes Sold Homes Sold Mom  \
# 0                  NaN                  NaN  NaN         1.0            NaN
# 1                 0.4%                  NaN  NaN        80.0           2.6%
# ...

# %%
illinois_df.columns
# Out:
# Index(['Worksheet Filter', 'Measure Display', 'Number of Records',
#        'Avg Sale To List', 'Avg Sale To List Mom', 'Avg Sale To List Yoy',
#        'City', 'Homes Sold', 'Homes Sold Mom', 'Homes Sold Yoy', 'Inventory',
#        'Inventory Mom', 'Inventory Yoy', 'Seasonally Adjusted', 'last_updated',
#        'Median Dom', 'Median Dom Mom', 'Median Dom Yoy', 'Median List Ppsf',
#        'Median List Ppsf Mom', 'Median List Ppsf Yoy', 'Median List Price',
#        'Median List Price Mom', 'Median List Price Yoy', 'Median Ppsf',
#        'Median Ppsf Mom', 'Median Ppsf Yoy', 'Median Sale Price',
#        'Median Sale Price Mom', 'Median Sale Price Yoy', 'months_of_supply',
#        'months_of_supply_mom', 'months_of_supply_yoy', 'New Listings',
#        'New Listings Mom', 'New Listings Yoy', 'off_market_in_two_weeks',
#        'off_market_in_two_weeks_mom', 'off_market_in_two_weeks_yoy',
#        'parent_metro_region', 'parent_metro_region_metro_code',
# ...

# %%
illinois_df.loc[illinois_df['State'] == 'Illinois']
# Out:
#         Worksheet Filter  Measure Display  Number of Records  \
# 206                Value              NaN                  1
# 236                Value              NaN                  1
# 244                Value              NaN                  1
# 658                Value              NaN                  1
# 706                Value              NaN                  1
# ...                  ...              ...                ...
# 9256473            Value              NaN                  1
# 9256474            Value              NaN                  1
# 9256475            Value              NaN                  1
# 9256476            Value              NaN                  1
# 9256477            Value              NaN                  1
#
#          Avg Sale To List Avg Sale To List Mom Avg Sale To List Yoy  \
# 206              0.889831                  NaN                  NaN
# 236              0.935897                25.0%                  NaN
# ...

# %%
illinois_df = illinois_df.loc[illinois_df['State Code'] == 'IL']

# %%
illinois_df.describe
# Out:
# <bound method NDFrame.describe of         Worksheet Filter  Measure Display  Number of Records  \
# 206                Value              NaN                  1
# 236                Value              NaN                  1
# 244                Value              NaN                  1
# 658                Value              NaN                  1
# 706                Value              NaN                  1
# ...                  ...              ...                ...
# 9256473            Value              NaN                  1
# 9256474            Value              NaN                  1
# 9256475            Value              NaN                  1
# 9256476            Value              NaN                  1
# 9256477            Value              NaN                  1
#
#          Avg Sale To List Avg Sale To List Mom Avg Sale To List Yoy  \
# 206              0.889831                  NaN                  NaN
# ...

# %%
illinois_df.to_csv('illinois_data_df.csv')
